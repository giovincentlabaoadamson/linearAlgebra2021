# %% [markdown]
# <a href="https://colab.research.google.com/github/giovincentlabaoadamson/linearAlgebra2021/blob/main/LinAlg_58051_Labao_Prelim_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
profit= np.array([1000, 2000, 13000, 12000])    
reach = np.array([5000, 100, 700, 20])

# %% [markdown]
# ###Question 1

# %%
''
# GRADED FUNCTION
# This is the starter code that you would use for Bebang's project. You may use Part 1 as a reference to complete this code.
# Please provide proper documentation, commenting, and necessary revisions to make the code clean and understandable.
# '''
## START OF FUNCTION
def month_profit_trace(profit, reach, make_figs=True): 
    if (profit.shape == (4,)) and (reach.shape == (4,)): 
        e_week1 = np.array((reach[0], profit[0]))         ## Setup the weekly efficiency vectors 
        e_week2 = np.array((reach[1], profit[1])) 
        e_week3 = np.array((reach[2], profit[2])) 
        e_week4 = np.array((reach[3], profit[3]))

        e_week1_2 = np.add(e_week1,e_week2)
        e_week1_2_3 = np.add(e_week1,(np.add(e_week2,e_week3)))  # For Week 4 plotting 
        e_week3_4 = np.add(e_week3,e_week4)

        e_month = np.add(e_week1_2,e_week3_4) # Computation for total of weeks
        e_month_magnitude = np.linalg.norm(e_month) #Computation for monthly efficiency
        alpha = 10**-6                                   
        theta = np.arctan(e_month[1]/(e_month[0]+alpha))  #Computation for displacement/theta
        theta = np.degrees(theta) 
       
        
        #plotting
        plt.figure(figsize=(16,5))
        plt.title('Bebang\'s Month Post Efficiency')
        plt.xlim(0,1.01*np.sum(reach))
        plt.ylim(-np.sum(np.abs(profit)),np.sum(np.abs(profit)))
        plt.xlabel('FB Post Reach Increment')
        plt.ylabel('Profit')
        plt.grid()
        n = 2
        
        #week1
        plt.quiver(0,0, e_week1[0], e_week1[1], 
                   angles='xy', scale_units='xy',scale=1, color='blue', width=0.0025,
                   label='Week 1: {:.2f}'.format(np.linalg.norm(e_week1)))
        
        #week2
        plt.quiver(e_week1[0],e_week1[1], e_week2[0],e_week2[1],
                   angles='xy', scale_units='xy',scale=1, color='orange', width=0.0025,
                   label='Week 2: {:.2f}'.format(np.linalg.norm(e_week2)))

        #week3
        plt.quiver(e_week1_2[0],e_week1_2[1],e_week3[0],e_week3[1],
                   angles='xy', scale_units='xy',scale=1, color='green', width=0.0025,
                   label='Week 3: {:.2f}'.format(np.linalg.norm(e_week3)))
        
        #week4
        plt.quiver(e_week1_2_3[0],e_week1_2_3[1],e_week4[0],e_week4[1],
                   angles='xy', scale_units='xy',scale=1, color='red', width=0.0025,
                   label='Week 4: {:.2f}'.format(np.linalg.norm(e_week4)))

                
        #monthly efficiency
        plt.quiver(0,0, e_month[0], e_month[1], 
                   angles='xy', scale_units='xy',scale=1, color='purple', width=0.005,
                  label='Efficiency: {:.2f} @ {:.2f}'.format(e_month_magnitude, theta))

        plt.legend(loc='upper left')

        if make_figs:
            plt.savefig(f'LinAlg-Lab2-Bebang Post Eff-{int(e_month_magnitude)}@{int(theta)}.png', dpi=300)

        plt.show()
    
    else:
        print('Vector elements is lacking') ## Make a more appropriate error statement. 

## END OF FUNCTION 
month_profit_trace(profit, reach, make_figs=True)

# %% [markdown]
# ### Question2

# %% [markdown]
# **Weekly Efficiencies**
# $$
# Week 1 = 5000\hat{x} + 1000\hat{y} \\
# Week 2 = 100\hat{x} + 4000\hat{y}\\
# Week 3 = 7000\hat{x} + 13000\hat{y} \\
# Week 4 = 200\hat{x} + 12000\hat{y}\\
# $$
#
# $$
# Week 1  =  \begin{bmatrix} 5000 \\ 1000\end{bmatrix},
# Week 2 =  \begin{bmatrix} 100 \\ 4000\end{bmatrix},
# Week 3 =  \begin{bmatrix} 700 \\ 13000\end{bmatrix},
# Week 4 =  \begin{bmatrix} 200 \\ 12000\end{bmatrix}\\
# $$
#
# **Monthtly Efficiency**
#
# $$
# Month = 5820\hat{x} + 28000\hat{y} \\
# $$
#
# $$
# Month=  \begin{bmatrix} 5820 \\ 28000\end{bmatrix}
# $$
